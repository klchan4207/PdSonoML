# %%
# this is a DEMO of _run.py with modification for demonstration
import os

os.system('python ../../__evalperform/0__check_DONEmodels.py')
print(' Step 1/7: ... checked all trained models')
# Out:
#  Step 1/7: ... checked all trained models

# %%
os.system('python ../../__evalperform/1__gen_modelINFO.py')
print(' Step 2/7: ... stored all loss info as csv file: modelINFO.csv')
# Out:
#  Step 2/7: ... stored all loss info as csv file: modelINFO.csv

# %%
os.system('python ../../__evalperform/2__repeat_pyfile.py')
print(' Step 3/7: ... stored all loss info as csv file: modelINFO.csv')
# Out:
#            Progress: 1 / 10
# [16:10:46] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fdc7e7fb160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 2 / 10
# [16:10:56] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fc7ac02a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 3 / 10
# [16:11:06] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fb0b982a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 4 / 10
# [16:11:15] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fb3f302a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 5 / 10
# [16:11:26] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7ffa3402a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 6 / 10
# [16:11:36] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7ff4e6f2a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 7 / 10
# [16:11:50] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7ffd75f29160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 8 / 10
# [16:12:01] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fade712a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 9 / 10
# [16:12:12] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fdc3192a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 10 / 10
# [16:12:25] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fb7af72a160>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#  Step 3/7: ... stored all loss info as csv file: modelINFO.csv

# %%
os.system('python ../../__evalperform/3__update_modelINFO.py')
print(' Step 4/7: ... updated modelINFO.csv as csv file: modelINFO_updated.csv')
# Out:
# 4_model
# 5_model
# 9_model
# 7_model
# 3_model
# 2_model
# 6_model
# 1_model
# 10_model
# 8_model
#  Step 4/7: ... updated modelINFO.csv as csv file: modelINFO_updated.csv

# %%
os.system('python ../../__evalperform/4__gen_modellist.py')
print(' Step 5/7: ... stored selected model as: modellist')
# Out:
#  Step 5/7: ... stored selected model as: modellist

# %%
os.system('python ../../__evalperform/5__repeat_pyfile.py')
print(' Step 6/7: ... stored intermediate values as csv file: _INT_dict.csv')
print('           ... stored selected model info as: _TrainedModel_INFO')
# Out:
#            Progress: 1 / 10
# [16:12:40] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:12:40.744233: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fd3b5127040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 2 / 10
# [16:12:54] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:12:54.694139: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fbb61727040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 3 / 10
# [16:13:06] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:13:06.536177: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7f8d1ff27040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 4 / 10
# [16:13:16] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:13:17.156047: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7f9502f27040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 5 / 10
# [16:13:26] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:13:27.062805: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fb058027040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 6 / 10
# [16:13:36] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:13:36.913340: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7f83f7827040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 7 / 10
# [16:13:46] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:13:46.757489: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fa587927040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 8 / 10
# [16:13:56] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:13:56.782625: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7f9c8e027040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 9 / 10
# [16:14:06] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:14:06.597678: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7fdd8e127040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#            Progress: 10 / 10
# [16:14:16] /tmp/dgl_src/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: dlopen(/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/dgl/tensoradapter/tensorflow/libtensoradapter_tensorflow_2.7.0.dylib, 1): image not found
# Using backend: tensorflow
# 2023-04-20 16:14:16.602708: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Exception ignored in: <function _CheckpointRestoreCoordinatorDeleter.__del__ at 0x7ff242827040>
# Traceback (most recent call last):
#   File "/Users/jacky/tf_mac_gpu/py39/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py", line 178, in __del__
# TypeError: 'NoneType' object is not callable
#  Step 6/7: ... stored intermediate values as csv file: _INT_dict.csv
#            ... stored selected model info as: _TrainedModel_INFO

# %%
os.system('python ../../__evalperform/6_avgINT.py --modellist=modellist')
os.system('python ../../__evalperform/6_avgPerform.py avgINT.csv --hide_plt=1')
print(' Step 7/7: ... stored performance plots at: avgPerform/')
# Out:
# 2023-04-20 16:14:25.677378: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  Step 7/7: ... stored performance plots at: avgPerform/

# %%
from IPython.display import Image
Image(filename='avgPerform/train.png')

# %%
Image(filename='avgPerform/test.png')

# %%
Image(filename='avgPerform/vali.png')
